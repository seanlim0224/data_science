# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_csv("C:/data_programming/wine.data")
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
df.columns=['class','alcohol','malic acid','ash', 'alcalinity of ash', 'magnesium','total phenols',
            'flavonoids','nonflavonoid phenols','proanthocyanidins','color intensity','hue',
            'OD280/OD315 of diluted wines','proline']

# %%
df
# Out:
#      class  alcohol  malic acid   ash  alcalinity of ash  magnesium  \
# 0        1    13.20        1.78  2.14               11.2        100
# 1        1    13.16        2.36  2.67               18.6        101
# 2        1    14.37        1.95  2.50               16.8        113
# 3        1    13.24        2.59  2.87               21.0        118
# 4        1    14.20        1.76  2.45               15.2        112
# ..     ...      ...         ...   ...                ...        ...
# 172      3    13.71        5.65  2.45               20.5         95
# 173      3    13.40        3.91  2.48               23.0        102
# 174      3    13.27        4.28  2.26               20.0        120
# 175      3    13.17        2.59  2.37               20.0        120
# 176      3    14.13        4.10  2.74               24.5         96
#
#      total phenols  flavonoids  nonflavonoid phenols  proanthocyanidins  \
# 0             2.65        2.76                  0.26               1.28
# ...

# %%
df.columns
# Out:
# Index(['class', 'alcohol', 'malic acid', 'ash', 'alcalinity of ash',
#        'magnesium', 'total phenols', 'flavonoids', 'nonflavonoid phenols',
#        'proanthocyanidins', 'color intensity', 'hue',
#        'OD280/OD315 of diluted wines', 'proline'],
#       dtype='object')

# %%
df.describe()
# Out:
#             class     alcohol  malic acid         ash  alcalinity of ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         magnesium  total phenols  flavonoids  nonflavonoid phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
df.dtypes
# Out:
# class                             int64
# alcohol                         float64
# malic acid                      float64
# ash                             float64
# alcalinity of ash               float64
# magnesium                         int64
# total phenols                   float64
# flavonoids                      float64
# nonflavonoid phenols            float64
# proanthocyanidins               float64
# color intensity                 float64
# hue                             float64
# OD280/OD315 of diluted wines    float64
# proline                           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# class                           0
# alcohol                         0
# malic acid                      0
# ash                             0
# alcalinity of ash               0
# magnesium                       0
# total phenols                   0
# flavonoids                      0
# nonflavonoid phenols            0
# proanthocyanidins               0
# color intensity                 0
# hue                             0
# OD280/OD315 of diluted wines    0
# proline                         0
# dtype: int64

# %%
count=df['class'].value_counts(ascending=True)
count
pd.DataFrame(count)
# Out:
#    class
# 3     48
# 1     58
# 2     71

# %%
count=df['alcohol'].value_counts(ascending=True)
count
pd.DataFrame(count)
# Out:
#        alcohol
# 13.20        1
# 12.07        1
# 11.87        1
# 11.56        1
# 11.45        1
# ...        ...
# 12.25        3
# 12.29        4
# 12.08        5
# 12.37        6
# 13.05        6
#
# [125 rows x 1 columns]

# %%
d=df['proanthocyanidins']==df['proanthocyanidins'].max()
df[d]
# Out:
#      class  alcohol  malic acid   ash  alcalinity of ash  magnesium  \
# 109      2    11.46        3.74  1.82               19.5        107
#
#      total phenols  flavonoids  nonflavonoid phenols  proanthocyanidins  \
# 109           3.18        2.58                  0.24               3.58
#
#      color intensity   hue  OD280/OD315 of diluted wines  proline
# 109              2.9  0.75                          2.81      562

# %%
d=df['alcohol']==df['alcohol'].min()
df[d]
# Out:
#      class  alcohol  malic acid  ash  alcalinity of ash  magnesium  \
# 114      2    11.03        1.51  2.2               21.5         85
#
#      total phenols  flavonoids  nonflavonoid phenols  proanthocyanidins  \
# 114           2.46        2.17                  0.52               2.01
#
#      color intensity   hue  OD280/OD315 of diluted wines  proline
# 114              1.9  1.71                          2.87      407

# %%
d=df.groupby('magnesium')['class'].count()
pd.DataFrame(d)
# Out:
#            class
# magnesium
# 70             1
# 78             3
# 80             5
# 81             1
# 82             1
# 84             3
# 85             6
# 86            11
# 87             3
# 88            13
# 89             5
# 90             4
# 91             2
# 92             5
# 93             2
# 94             6
# 95             3
# 96             8
# 97             5
# 98             9
# 99             1
# 100            3
# 101            9
# 102            7
# 103            5
# 104            3
# 105            2
# 106            4
# 107            4
# 108            4
# 110            3
# 111            3
# 112            6
# 113            2
# 115            2
# 116            3
# 117            1
# 118            3
# 119            1
# 120            3
# 121            1
# 122            1
# 123            1
# 124            1
# 126            1
# 128            1
# 132            1
# 134            1
# 136            1
# 139            1
# 151            1
# ...

# %%
df.groupby('class').count()
# Out:
#        alcohol  malic acid  ash  alcalinity of ash  magnesium  total phenols  \
# class
# 1           58          58   58                 58         58             58
# 2           71          71   71                 71         71             71
# 3           48          48   48                 48         48             48
#
#        flavonoids  nonflavonoid phenols  proanthocyanidins  color intensity  \
# class
# 1              58                    58                 58               58
# 2              71                    71                 71               71
# 3              48                    48                 48               48
#
#        hue  OD280/OD315 of diluted wines  proline
# class
# 1       58                            58       58
# 2       71                            71       71
# 3       48                            48       48

# %%
df.hist(figsize=(20,10), grid=False, layout=(3,5), bins=30)
# Out:
# array([[<Axes: title={'center': 'class'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'malic acid'}>,
#         <Axes: title={'center': 'ash'}>,
#         <Axes: title={'center': 'alcalinity of ash'}>],
#        [<Axes: title={'center': 'magnesium'}>,
#         <Axes: title={'center': 'total phenols'}>,
#         <Axes: title={'center': 'flavonoids'}>,
#         <Axes: title={'center': 'nonflavonoid phenols'}>,
#         <Axes: title={'center': 'proanthocyanidins'}>],
#        [<Axes: title={'center': 'color intensity'}>,
#         <Axes: title={'center': 'hue'}>,
#         <Axes: title={'center': 'OD280/OD315 of diluted wines'}>,
#         <Axes: title={'center': 'proline'}>, <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(20,7))
sns.swarmplot(x='class', y='ash', data=df, hue='class')
sns.violinplot(x='class', y='ash', data=df)
# Out:
# <Axes: xlabel='class', ylabel='ash'>

# %%
plt.figure(figsize=(20,7))
sns.swarmplot(x='class', y='alcohol', data=df, hue='class')
sns.violinplot(x='class', y='alcohol', data=df)
# Out:
# <Axes: xlabel='class', ylabel='alcohol'>

# %%
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(x='class',y='alcohol', data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(x='class',y='malic acid', data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(x='class',y='alcalinity of ash', data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(x='class',y='color intensity', data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(x='class',y='hue', data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Seaborn Strip Plot Graph')

sns.stripplot(x='class',y='magnesium', data=df)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['malic acid'],bins=5, alpha=0.5, label='malic acid', kde=True)
sns.histplot(df['ash'],bins=5, alpha=0.5, label='ash', color='r',kde=True)

plt.xlim(1,6)
plt.xlabel('acid&ash')
plt.ylabel('count')
plt.title('KDE')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.title('14x14Heat Map Graph')

correlation_df=df.corr()
upp_mat = np.triu(correlation_df)

sns.heatmap(correlation_df, annot=True, cmap='RdYlGn', mask=upp_mat)
# Out:
# <Axes: title={'center': '14x14Heat Map Graph'}>
