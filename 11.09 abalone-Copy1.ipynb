# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_csv("C:/data_programming/abalone.data")

# %%
df.columns = ['Sex', 'Length','Diam','Height','Whole','Shucked', 'Viscera', 'Shell', 'Rings']

# %%
df
# Out:
#      Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0      M   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 1      F   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 2      M   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 3      I   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# 4      I   0.425  0.300   0.095  0.3515   0.1410   0.0775  0.1200      8
# ...   ..     ...    ...     ...     ...      ...      ...     ...    ...
# 4171   F   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4172   M   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4173   M   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4174   F   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4175   M   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4176 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df['Sex']=le.fit_transform(df['Sex'])

# %%
df
# Out:
#       Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0       2   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 1       0   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 2       2   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 3       1   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# 4       1   0.425  0.300   0.095  0.3515   0.1410   0.0775  0.1200      8
# ...   ...     ...    ...     ...     ...      ...      ...     ...    ...
# 4171    0   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4172    2   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4173    2   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4174    0   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4175    2   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4176 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Sex        0
# Length     0
# Diam       0
# Height     0
# Whole      0
# Shucked    0
# Viscera    0
# Shell      0
# Rings      0
# dtype: int64

# %%
df.describe()
# Out:
#                Sex       Length         Diam       Height        Whole  \
# count  4176.000000  4176.000000  4176.000000  4176.000000  4176.000000
# mean      1.052682     0.524009     0.407892     0.139527     0.828818
# std       0.822208     0.120103     0.099250     0.041826     0.490424
# min       0.000000     0.075000     0.055000     0.000000     0.002000
# 25%       0.000000     0.450000     0.350000     0.115000     0.441500
# 50%       1.000000     0.545000     0.425000     0.140000     0.799750
# 75%       2.000000     0.615000     0.480000     0.165000     1.153250
# max       2.000000     0.815000     0.650000     1.130000     2.825500
#
#           Shucked      Viscera        Shell        Rings
# count  4176.00000  4176.000000  4176.000000  4176.000000
# mean      0.35940     0.180613     0.238852     9.932471
# std       0.22198     0.109620     0.139213     3.223601
# min       0.00100     0.000500     0.001500     1.000000
# ...

# %%
df.mode(0)
# Out:
#    Sex  Length  Diam  Height   Whole  Shucked  Viscera  Shell  Rings
# 0  2.0   0.550  0.45    0.15  0.2225    0.175   0.1715  0.275    9.0
# 1  NaN   0.625   NaN     NaN     NaN      NaN      NaN    NaN    NaN

# %%
plt.boxplot([df['Length'], df['Diam']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22bb752f750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22bb753d210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22bb752e950>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x22bb753ead0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x22bb753f5d0>,
# ...
#  'means': []}

# %%
df.Length.min()
# Out:
# 0.075

# %%
df1=df[df.Length>0.2]

# %%
df1=df[df.Diam>0.15]

# %%
plt.boxplot([df1['Length'], df1['Diam']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22bc26fb910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22bc2783f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22bc2782090>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x22bc2790d50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x22bc2791690>,
# ...
#  'means': []}

# %%
df.groupby('Rings')['Shucked'].mean()
# Out:
# Rings
# 1     0.001000
# 2     0.004500
# 3     0.011767
# 4     0.024719
# 5     0.061696
# 6     0.123158
# 7     0.182657
# 8     0.293773
# 9     0.387938
# 10    0.447217
# 11    0.503977
# 12    0.472781
# 13    0.434638
# 14    0.427190
# 15    0.404216
# 16    0.421716
# 17    0.467052
# 18    0.446833
# 19    0.440625
# 20    0.458115
# 21    0.447464
# 22    0.405000
# 23    0.399444
# 24    0.600250
# 25    0.426500
# 26    0.384000
# 27    0.539000
# 29    0.705500
# Name: Shucked, dtype: float64

# %%
df.groupby('Rings')['Shucked', 'Whole', 'Shell'].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17536\329087056.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Rings')['Shucked', 'Whole', 'Shell'].mean()
#         Shucked     Whole     Shell
# Rings
# 1      0.001000  0.002000  0.001500
# 2      0.004500  0.015000  0.005000
# 3      0.011767  0.028400  0.008933
# 4      0.024719  0.059605  0.018000
# 5      0.061696  0.125500  0.036770
# 6      0.123158  0.273174  0.078388
# 7      0.182657  0.397386  0.111648
# 8      0.293773  0.640753  0.178609
# 9      0.387938  0.852013  0.236509
# 10     0.447217  1.008748  0.282976
# 11     0.503977  1.142559  0.319866
# 12     0.472781  1.102904  0.321157
# 13     0.434638  1.075453  0.320828
# 14     0.427190  1.079992  0.329960
# 15     0.404216  1.046118  0.323333
# 16     0.421716  1.133388  0.377858
# 17     0.467052  1.234328  0.393414
# 18     0.446833  1.194333  0.386762
# ...

# %%
df.hist(figsize=(20, 10), grid=False, bins = 30)
# Out:
# array([[<Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diam'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole'}>,
#         <Axes: title={'center': 'Shucked'}>],
#        [<Axes: title={'center': 'Viscera'}>,
#         <Axes: title={'center': 'Shell'}>,
#         <Axes: title={'center': 'Rings'}>]], dtype=object)
