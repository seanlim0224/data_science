# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("C:/data_programming/abaloneage.csv")

# %%
data
# Out:
#       Diameter  Height  Whole_Weight  Viscra_Weight  Shell_Weight  Group
# 0        0.525   0.195        1.3700         0.2955        0.4070    2.0
# 1        0.275   0.095        0.2170         0.0435        0.0900    1.0
# 2        0.470   0.165        0.9975         0.2420        0.3300    0.0
# 3        0.450   0.140        1.0130         0.2160        0.3600    0.0
# 4        0.380   0.135        0.6810         0.1420        0.1700    0.0
# ...        ...     ...           ...            ...           ...    ...
# 997      0.450   0.160        0.9980         0.2140        0.3010    0.0
# 998      0.260   0.100        0.1920         0.0585        0.0700    1.0
# 999      0.505   0.175        1.2075         0.2620        0.3900    0.0
# 1000     0.300   0.105        0.3040         0.0610        0.0805    1.0
# 1001     0.465   0.150        1.0270         0.1880        0.1760    0.0
#
# [1002 rows x 6 columns]

# %%
data.loc[data['Group']==0.0,['Group']]='Year0'
data.loc[data['Group']==1.0,['Group']]='Year1'
data.loc[data['Group']==2.0,['Group']]='Year2'

# %%
data
# Out:
#       Diameter  Height  Whole_Weight  Viscra_Weight  Shell_Weight  Group
# 0        0.525   0.195        1.3700         0.2955        0.4070  Year2
# 1        0.275   0.095        0.2170         0.0435        0.0900  Year1
# 2        0.470   0.165        0.9975         0.2420        0.3300  Year0
# 3        0.450   0.140        1.0130         0.2160        0.3600  Year0
# 4        0.380   0.135        0.6810         0.1420        0.1700  Year0
# ...        ...     ...           ...            ...           ...    ...
# 997      0.450   0.160        0.9980         0.2140        0.3010  Year0
# 998      0.260   0.100        0.1920         0.0585        0.0700  Year1
# 999      0.505   0.175        1.2075         0.2620        0.3900  Year0
# 1000     0.300   0.105        0.3040         0.0610        0.0805  Year1
# 1001     0.465   0.150        1.0270         0.1880        0.1760  Year0
#
# [1002 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(data=data, x="Group")
plt.xlabel("Group")
plt.ylabel("Count")
plt.title("Label Count")
# Out:
# Text(0.5, 1.0, 'Label Count')

# %%
data.loc[data['Group']=='Year0',['Group']]=0
data.loc[data['Group']=='Year1',['Group']]=1
data.loc[data['Group']=='Year2',['Group']]=2

# %%
G1data=data.loc[data.Group==0,['Diameter','Height','Whole_Weight','Viscra_Weight','Shell_Weight']]
G2data=data.loc[data.Group==1,['Diameter','Height','Whole_Weight','Viscra_Weight','Shell_Weight']]
G3data=data.loc[data.Group==2,['Diameter','Height','Whole_Weight','Viscra_Weight','Shell_Weight']]

# %%
plt.figure(figsize=(10,6))
sns.histplot(G1data['Diameter'],bins=7,alpha=0.5,label='Year0',kde=True)
sns.histplot(G2data['Diameter'],bins=7,alpha=0.5,label='Year1',color='r',kde=True)
sns.histplot(G3data['Diameter'],bins=7,alpha=0.5,label='Year2',color='g',kde=True)

plt.xlabel('Diameter')
plt.ylabel('count')
plt.title('Abaloneage Diameter - KDE(Kernel Density Estimator)')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('Abaloneage Diameter Seaborn Box Plot Graph')

sns.boxplot(x='Group',y='Diameter',hue='Group',data=data)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('Abaloneage Height Seaborn Box Plot Graph')

sns.boxplot(x='Group',y='Height',hue='Group',data=data)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('Abaloneage Diameter Violin Plot Graph')
sns.violinplot(x='Group',y='Diameter',hue='Group',data=data)
# Out:
# <Axes: title={'center': 'Abaloneage Diameter Violin Plot Graph'}, xlabel='Group', ylabel='Diameter'>

# %%
plt.figure(figsize=(10,6))
plt.title('Abaloneage Diameter Violin Plot Graph')
sns.violinplot(x='Group',y='Height',hue='Group',data=data)
# Out:
# <Axes: title={'center': 'Abaloneage Diameter Violin Plot Graph'}, xlabel='Group', ylabel='Height'>

# %%
data
# Out:
#       Diameter  Height  Whole_Weight  Viscra_Weight  Shell_Weight Group
# 0        0.525   0.195        1.3700         0.2955        0.4070     2
# 1        0.275   0.095        0.2170         0.0435        0.0900     1
# 2        0.470   0.165        0.9975         0.2420        0.3300     0
# 3        0.450   0.140        1.0130         0.2160        0.3600     0
# 4        0.380   0.135        0.6810         0.1420        0.1700     0
# ...        ...     ...           ...            ...           ...   ...
# 997      0.450   0.160        0.9980         0.2140        0.3010     0
# 998      0.260   0.100        0.1920         0.0585        0.0700     1
# 999      0.505   0.175        1.2075         0.2620        0.3900     0
# 1000     0.300   0.105        0.3040         0.0610        0.0805     1
# 1001     0.465   0.150        1.0270         0.1880        0.1760     0
#
# [1002 rows x 6 columns]

# %%
data5 = data.loc[:,['Diameter','Height','Whole_Weight','Viscra_Weight','Shell_Weight']]

# %%
plt.figure(figsize=(10,6))
plt.title('5x5 Heat Map Graph')

correlation_data5 = data5.corr()
sns.heatmap(correlation_data5, annot=True, cmap='YlGnBu')
# Out:
# <Axes: title={'center': '5x5 Heat Map Graph'}>

# %%
data6 = data.loc[:,['Diameter','Height','Whole_Weight','Viscra_Weight','Shell_Weight','Group']]

# %%
pp = sns.pairplot(data6,height=3.3,aspect=1.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("C:/data_programming/abaloneage.csv")

# %%
data
# Out:
#       Diameter  Height  Whole_Weight  Viscra_Weight  Shell_Weight  Group
# 0        0.525   0.195        1.3700         0.2955        0.4070    2.0
# 1        0.275   0.095        0.2170         0.0435        0.0900    1.0
# 2        0.470   0.165        0.9975         0.2420        0.3300    0.0
# 3        0.450   0.140        1.0130         0.2160        0.3600    0.0
# 4        0.380   0.135        0.6810         0.1420        0.1700    0.0
# ...        ...     ...           ...            ...           ...    ...
# 997      0.450   0.160        0.9980         0.2140        0.3010    0.0
# 998      0.260   0.100        0.1920         0.0585        0.0700    1.0
# 999      0.505   0.175        1.2075         0.2620        0.3900    0.0
# 1000     0.300   0.105        0.3040         0.0610        0.0805    1.0
# 1001     0.465   0.150        1.0270         0.1880        0.1760    0.0
#
# [1002 rows x 6 columns]

# %%
newdf = data.loc[:,['Diameter','Height','Group']]

# %%
newdf
# Out:
#       Diameter  Height Group
# 0        0.525   0.195     2
# 1        0.275   0.095     1
# 2        0.470   0.165     0
# 3        0.450   0.140     0
# 4        0.380   0.135     0
# ...        ...     ...   ...
# 997      0.450   0.160     0
# 998      0.260   0.100     1
# 999      0.505   0.175     0
# 1000     0.300   0.105     1
# 1001     0.465   0.150     0
#
# [1002 rows x 3 columns]

# %%
newdf.loc[data['Diameter']>0.4,['Diameter']]='Big'
newdf.loc[data['Diameter']<0.4,['Diameter']]='Small'

# %%
plt.figure(figsize=(10,6))
plt.title('Diameter Big Or Small')
sns.countplot(x='Group',hue='Diameter',data=newdf)
# Out:
# <Axes: title={'center': 'Diameter Big Or Small'}, xlabel='Group', ylabel='count'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('C:/data_programming/05_data1.xlsx')
df
# Out:
#         no  city_code  gender  age_code  height  weight  waist  systolic  \
# 0        1         36       1         9     165      60   72.1       127
# 1        5         41       2        12     155      50   75.2       144
# 2        6         27       1         9     185      85   94.0       114
# 3        7         44       1         9     165      80   93.0       112
# 4        9         41       2        17     150      50   82.0       136
# ...    ...        ...     ...       ...     ...     ...    ...       ...
# 2995  7648         31       2        11     155      55   68.0       132
# 2996  7650         42       1        13     155      60   79.0       123
# 2997  7651         41       1         9     165      60   85.0       118
# 2998  7652         42       1         9     180      90   97.0       148
# 2999  7659         44       1        11     160      65   89.8       125
#
#       diastolic  blood_sugar  cholesterol  triglycerides   HDL  LDL  \
# ...

# %%
data6 = df.loc[:,['gender','age_code','weight', 'height','blood_sugar']]

# %%
data6.loc[data6['gender']==1,['gender']]='M'
data6.loc[data6['gender']==2,['gender']]='F'

# %%
data6.loc[df['blood_sugar']>120,['blood_sugar']]='Over'
data6.loc[df['blood_sugar']<120 ,['blood_sugar']]='Under'

# %%
blood_sugar = data6.groupby(['gender','blood_sugar'])['blood_sugar'].count()
blood_sugar = blood_sugar.to_frame(name='count')
blood_sugar = blood_sugar.reset_index()

# %%
fig = plt.figure(figsize=(12,12))

area1 = fig.add_subplot(2,1,1)

ax1=sns.barplot(x='gender',y='count',hue='blood_sugar',data=blood_sugar,ax=area1)


fig.suptitle('2020 Health Check Blood Sugar',fontweight='bold')
area1.set_title('Blood Sugar')

plt.show()
